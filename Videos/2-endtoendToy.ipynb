# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Machine learning Campusx\Data\student_placement_data.csv")

# %%
df.head()
# Out:
#    index  cgpa   iq  placement
# 0      1  7.70   84          1
# 1      2  7.06   99          1
# 2      3  7.85  100          1
# 3      4  8.72   93          1
# 4      5  6.97  103          0

# %%
df.drop(columns=['index'], inplace=True)

# %%
df.head()
# Out:
#    cgpa   iq  placement
# 0  7.70   84          1
# 1  7.06   99          1
# 2  7.85  100          1
# 3  8.72   93          1
# 4  6.97  103          0

# %%
#steps 

# preprocess eda feature selection
# extract input and output columns
# scaling if needed
# train test split
# train the model
# evaluation
# deployment

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(df['cgpa'] , df['iq'] , c=df['placement'])
plt.xlabel("cgpa")
plt.ylabel("iq")
plt.title("CGPA vs IQ")
# Out:
# Text(0.5, 1.0, 'CGPA vs IQ')

# %%
X = df[['cgpa' , 'iq']]
y = df['placement']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train ,y_test = train_test_split(X,y , test_size=0.1 , random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train , y_train)  # this is model training using train set
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test) #predicted values based on our model params

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test , y_pred))
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(
    X_train,
    y_train.values,
    clf=lr
)

plt.xlabel("CGPA")
plt.ylabel("IQ")
plt.title("Decision Boundary")
plt.show()

# %%
import pickle
pickle.dump(lr,open("./Models/endtoendmodel.pkl",'wb'))
