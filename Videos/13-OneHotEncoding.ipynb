# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Machine learning Campusx\Data\cars.csv")

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].nunique()
# Out:
# 32

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %% [markdown]
# ## Pandas way

# %%
pandas_df = pd.get_dummies(df , columns = ["fuel" , 'owner'],drop_first = True)

# %%
pandas_df[['fuel_Diesel', 'fuel_LPG',
       'fuel_Petrol', 'owner_Fourth & Above Owner', 'owner_Second Owner',
       'owner_Test Drive Car', 'owner_Third Owner']]= pandas_df[['fuel_Diesel', 'fuel_LPG',
       'fuel_Petrol', 'owner_Fourth & Above Owner', 'owner_Second Owner',
       'owner_Test Drive Car', 'owner_Third Owner']].astype(int)

# %% [markdown]
# ## Scikit learn way

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop = "first" , dtype = np.int32)

# %%
X_train_new = ohe.fit_transform(X_train[['fuel', "owner"]]).toarray() #cause it gives a sparse matrix thats why use to array
X_test_new = ohe.transform(X_test[['fuel', 'owner']]).toarray()

# %%
X_test_new.shape
# Out:
# (1626, 7)

# %%
np.hstack((X_train[['brand','km_driven']].values , X_train_new)).shape
# Out:
# (6502, 9)

# %%
np.hstack((X_test[['brand','km_driven']].values , X_test_new)).shape
# Out:
# (1626, 9)

# %%
counts = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

repl = counts[counts <=threshold].index
repl
# Out:
# Index(['Nissan', 'Jaguar', 'Volvo', 'Datsun', 'Mercedes-Benz', 'Fiat', 'Audi',
#        'Lexus', 'Jeep', 'Mitsubishi', 'Land', 'Force', 'Isuzu', 'Ambassador',
#        'Kia', 'MG', 'Daewoo', 'Ashok', 'Opel', 'Peugeot'],
#       dtype='object', name='brand')

# %%
pd.get_dummies(df['brand'].replace(repl , "uncommon"))
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 0     False      False  False  False    False     False    True    False
# 1     False      False  False  False    False     False   False    False
# 2     False      False  False   True    False     False   False    False
# 3     False      False  False  False     True     False   False    False
# 4     False      False  False  False    False     False    True    False
# ...     ...        ...    ...    ...      ...       ...     ...      ...
# 8123  False      False  False  False     True     False   False    False
# 8124  False      False  False  False     True     False   False    False
# 8125  False      False  False  False    False     False    True    False
# 8126  False      False  False  False    False     False   False    False
# 8127  False      False  False  False    False     False   False    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# ...
